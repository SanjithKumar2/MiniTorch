# %%
from MiniTorch.nets.base import Net
from MiniTorch.nets.layers import Conv2D, Linear, MaxPool2d, PReLU, ReLU, SoftMax, Flatten, Tanh, Sigmoid
from MiniTorch.optimizers import SGD
from MiniTorch.losses import CCE, MSE
import matplotlib.pyplot as plt
import jax
import time
from MiniTorch.plotutils import show_conv_out
import jax.numpy as jnp

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1)
X, y = mnist['data'], mnist['target']

# %%
X = X.to_numpy()
y = y.to_numpy()
n_samples = X.shape[0]
image_size = (28, 28)
X_images = X.reshape(n_samples, 28,28)

# %%
def get_training_data(X,Y,train_size):
    X_tra = X[:train_size]
    Y_tra = Y[:train_size]
    Y_tra = [[1 if j == int(i) else 0 for j in range(10)] for i in Y_tra]
    Y_tra = jnp.array(Y_tra)
    X_tra = jnp.reshape(jnp.array(X_tra),(train_size, 28,28))
    X_tra = jnp.expand_dims(X_tra,axis = 1)
    X_tra = X_tra.astype('float32')/255.
    return X_tra,Y_tra
X_tra, Y_tra = get_training_data(X,y,10000)

# %%
crit = CCE()

# %%
net_3 = Net(
    [
        Conv2D(1,4,20, accumulate_grad_norm=True, accumulate_params=True, initialization='xavier'),
        MaxPool2d(2,2),
        Flatten(),
        Linear(2880, 50, accumulate_grad_norm=True,accumulate_parameters=True,initialization='xavier'),
        Linear(50, 50, accumulate_grad_norm=True,accumulate_parameters=True,initialization='xavier'),
        Sigmoid(),
        Linear(50, 10,accumulate_grad_norm=True,accumulate_parameters=True,initialization='xavier'),
        SoftMax()
    ],
    reproducibility_key=20
)

# %%
X_example, y_example = jnp.expand_dims(X_tra[0], axis = 0), jnp.expand_dims(Y_tra[0], axis = 0)

# %%
def get_top_1_eigen_value(model, data_sample, crit):
    x,y = data_sample
    out = model.forward(x)
    los = crit.loss(out,y)
    ini_grad = crit.backward(los)
    model.backward(ini_grad)

# %%
get_top_1_eigen_value(net_3,(X_example,y_example), crit)

# %%
# Out:
# {'dL_dW': Array([[ 0.02608397,  0.02804006,  0.02075754,  0.1542476 ,  0.03187599,
#          -0.436037  ,  0.02418122,  0.05980736,  0.02364981,  0.06739344],
#         [ 0.02641419,  0.02839504,  0.02102032,  0.15620033,  0.03227954,
#          -0.4415571 ,  0.02448735,  0.0605645 ,  0.02394921,  0.06824663],
#         [ 0.02811357,  0.03022186,  0.02237269,  0.16624963,  0.03435627,
#          -0.46996513,  0.02606276,  0.06446099,  0.02549001,  0.07263735],
#         [ 0.02624981,  0.02821833,  0.02088951,  0.15522826,  0.03207865,
#          -0.43880922,  0.02433496,  0.0601876 ,  0.02380017,  0.06782192],
#         [ 0.03126592,  0.03361061,  0.02488132,  0.18489106,  0.03820861,
#          -0.48493597,  0.026893  ,  0.0665144 ,  0.026302  ,  0.07495122],
#         [ 0.02806109,  0.03016544,  0.02233092,  0.16593929,  0.03429214,
#          -0.4690878 ,  0.02601411,  0.06434065,  0.02544243,  0.07250175],
#         [ 0.02492113,  0.02679001,  0.01983215,  0.14737114,  0.03045494,
#          -0.41659817,  0.02310321,  0.05714111,  0.02259549,  0.06438901],
#         [ 0.0294751 ,  0.03168549,  0.02345619,  0.17430104,  0.03602013,
#          -0.49272537,  0.02732497,  0.0675828 ,  0.02672448,  0.07615515],
#         [ 0.03128349,  0.0336295 ,  0.0248953 ,  0.18499495,  0.03823008,
#          -0.5229556 ,  0.02900145,  0.07172922,  0.02836411,  0.0808275 ],
#         [ 0.0260957 ,  0.02805266,  0.02076687,  0.15431693,  0.03189033,
#          -0.43623298,  0.02419209,  0.05983424,  0.02366044,  0.06742374],
#         [ 0.02733746,  0.02938755,  0.02175506,  0.16166013,  0.03340783,
#          -0.45699123,  0.02534327,  0.06268147,  0.02478633,  0.07063212],
#         [ 0.02987154,  0.03211167,  0.02377168,  0.17664541,  0.03650461,
#          -0.49935257,  0.0276925 ,  0.0684918 ,  0.02708393,  0.07717944],
#         [ 0.02817699,  0.03029004,  0.02242316,  0.16662468,  0.03443378,
#          -0.47102535,  0.02612156,  0.06460641,  0.02554751,  0.07280121],
#         [ 0.02694109,  0.02896145,  0.02143963,  0.15931617,  0.03292344,
#          -0.45036516,  0.02497581,  0.06177263,  0.02442695,  0.069608  ],
#         [ 0.02857791,  0.03072102,  0.0227422 ,  0.1689955 ,  0.03492372,
#          -0.4777273 ,  0.02649323,  0.06552565,  0.02591102,  0.07383706]],      dtype=float32),
#  'dL_dinput': Array([[-0.1363564 , -0.1072804 ,  0.03362482,  0.03123859,  0.00099631,
#          -0.08187255,  0.33095935, -0.11396892,  0.04533034,  0.20459948,
#          -0.26070175,  0.29073545,  0.17209291,  0.19719607, -0.04338368,
#          -0.33226672,  0.0794448 ,  0.3255509 ,  0.21430248, -0.21729578,
#           0.15628327,  0.10889851,  0.26818085,  0.21139757,  0.00808677,
#           0.11393992, -0.08580536,  0.13091119,  0.20035544, -0.05006288,
#          -0.18289736, -0.26413524, -0.13057926,  0.30854347, -0.0565357 ,
#          -0.3301864 ,  0.31029543, -0.03501045, -0.06852073,  0.27676913,
#           0.35067394,  0.030598  ,  0.06293233,  0.03326771, -0.00670776,
#          -0.20452106, -0.12683952, -0.01435986,  0.21540314, -0.11115033]],      dtype=float32),
#  'dL_db': Array([[ 0.056665  ,  0.06091442,  0.04509382,  0.33508858,  0.06924764,
#          -0.9472499 ,  0.05253145,  0.12992594,  0.05137702,  0.14640601]],      dtype=float32)}
