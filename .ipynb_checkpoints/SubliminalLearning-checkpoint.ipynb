# %%
from MiniTorch.nets.base import Net
from MiniTorch.nets.layers import Conv2D, Linear, Flatten, ReLU, SoftMax
from MiniTorch.optimizers import SGD
from MiniTorch.losses import CCE
from MiniTorch.inference.core_infer import LRP
import matplotlib.pyplot as plt
import jax.numpy as jnp
import jax
import torch
import torch.nn.functional as F
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 9
#       7 import jax.numpy as jnp
#       8 import jax
# ----> 9 import torch
#      10 import torch.nn.functional as F
#
# File ~\miniconda3\envs\xformers-env\Lib\site-packages\torch\__init__.py:274
#     270                     raise err
#     272         kernel32.SetErrorMode(prev_error_mode)
# --> 274     _load_dll_libraries()
#     275     del _load_dll_libraries
#     278 def _preload_cuda_deps(lib_folder: str, lib_name: str) -> None:
#
# File ~\miniconda3\envs\xformers-env\Lib\site-packages\torch\__init__.py:250, in _load_dll_libraries()
#     248 is_loaded = False
#     249 if with_load_library_flags:
# --> 250     res = kernel32.LoadLibraryExW(dll, None, 0x00001100)
#     251     last_error = ctypes.get_last_error()
#     252     if res is None and last_error != 126:
#
# KeyboardInterrupt:

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1)
X, y = mnist['data'], mnist['target']

# %%
def get_training_data(X,Y,train_size):
    X_tra = X[:train_size]
    Y_tra = Y[:train_size]
    Y_tra = [[1 if j == int(i) else 0 for j in range(10)] for i in Y_tra]
    Y_tra = jnp.array(Y_tra)
    X_tra = jnp.reshape(jnp.array(X_tra),(train_size, 28,28))
    X_tra = jnp.expand_dims(X_tra,axis = 1)
    X_tra = X_tra.astype('float32')/255.
    return X_tra,Y_tra
X_tra, Y_tra = get_training_data(X,y,40000)

# %%
net = Net(y 
    [
        Conv2D(1,4,15,stride=2, accumulate_grad_norm=True, initialization="he", bias=False),
        Flatten(),
        Linear(2535, 50, accumulate_grad_norm=True, initialization="he"),
        ReLU(),
        Linear(50, 50, accumulate_grad_norm=True, initialization="he"),
        ReLU(),
        Linear(50, 10, accumulate_grad_norm=True, initialization="he"),
        SoftMax()
    ],
    reproducibility_key=21
)
