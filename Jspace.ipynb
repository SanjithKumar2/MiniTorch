# %%
import numpy as np

# %%
W = np.random.randn(3, 4)
x = np.random.randn(1, 3)
b = np.random.randn(1, 4)

# %%
x @ W + b
# Out:
# array([[-1.45176993e-01,  6.55050126e-04, -8.49061396e-01,
#         -1.42827399e+00]])

# %%
x[0, 1] = 3

# %%
x @ W + b
# Out:
# array([[-2.76280458, -0.94728013,  0.5586713 , -3.22510018]])

# %%
x
# Out:
# array([[-0.10400495,  3.        ,  0.66144553]])
